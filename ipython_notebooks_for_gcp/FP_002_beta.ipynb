# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
# fix seed for reproducibility
np.random.seed(seed=12345)

# %%
# load (download if needed) the MNIST dataset
file = open('data.pkl','rb')
display_data=pickle.load(file)
x_data=display_data["image"]
y_data=display_data["label"]

# %%
new_y =[]
# tokenize the labels
for i in y_data:
    if(i == '-Fire-Smoke'):
        new_y.append(0)
    elif (i == '-Fire+Smoke'):
        new_y.append(1)
    elif (i == '+Fire+Smoke'):
        new_y.append(2)

# %%
# split the data into training dataset and validation dataset
from sklearn.model_selection import train_test_split
seed =12345
XTrain, XTest, yTrain, yTest = train_test_split(x_data,new_y,test_size=0.20,random_state=seed)
XTrain = (XTrain-np.min(XTrain))/(np.max(XTrain)-np.min(XTrain))
XTest = (XTest-np.min(XTest))/(np.max(XTest)-np.min(XTest))
valid_data = []
valid_data.append(XTest)
class_names = np.unique(yTrain)

# %%
#one hot encoding of the targets
from keras.utils import np_utils
yTrain = np_utils.to_categorical(yTrain)
yTest = np_utils.to_categorical(yTest)
valid_data.append(yTest)
# Out:
# Using TensorFlow backend.

# %%
from keras.applications import VGG16
from keras import models
from keras import layers
from keras import optimizers

#Load the VGG model
vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(300, 600, 3))


    
# Freeze the last 2 layers
print("Freeze the last 2 layers")
for layer in vgg_conv.layers[:-2]:
    layer.trainable = False

# Create the model
model = models.Sequential()

# Add the vgg convolutional base model
model.add(vgg_conv)

# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])
# Train the model

history=model.fit(XTrain, yTrain, epochs=25, batch_size=25,validation_data=valid_data)

print(history.history.keys())
# Save the model
fileName="freeze_last2.h5"
model.save(fileName)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Freeze the last 2 layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 9, 18, 512)        14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              84935680
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 99,653,443
# Trainable params: 87,298,563
# Non-trainable params: 12,354,880
# _________________________________________________________________
# Train on 550 samples, validate on 138 samples
# Epoch 1/25
# 550/550 [==============================] - 47s 86ms/step - loss: 10.0328 - acc: 0.3436 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 2/25
# 550/550 [==============================] - 33s 59ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 3/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 4/25
# 550/550 [==============================] - 33s 59ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 5/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 6/25
# 550/550 [==============================] - 33s 59ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 7/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 8/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 9/25
# 550/550 [==============================] - 33s 59ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 10/25
# 550/550 [==============================] - 33s 59ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 11/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 12/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 13/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 14/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 15/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 16/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 17/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 18/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 19/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 20/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 21/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 22/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 23/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 24/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# Epoch 25/25
# 550/550 [==============================] - 33s 60ms/step - loss: 10.7552 - acc: 0.3327 - val_loss: 11.4462 - val_acc: 0.2899
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# Freeze the last 4 layers
print("Freeze the last 4 layers")
for layer in vgg_conv.layers[:-4]:
    layer.trainable = False

# Create the model
model = models.Sequential()

# Add the vgg convolutional base model
model.add(vgg_conv)

# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])
# Train the model

history=model.fit(XTrain, yTrain, epochs=25, batch_size=25,validation_data=valid_data)

print(history.history.keys())
# Save the model
fileName="freeze_last4.h5"
model.save(fileName)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Freeze the last 4 layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 9, 18, 512)        14714688
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              84935680
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 99,653,443
# Trainable params: 87,298,563
# Non-trainable params: 12,354,880
# _________________________________________________________________
# Train on 550 samples, validate on 138 samples
# Epoch 1/25
# 550/550 [==============================] - 36s 65ms/step - loss: 2.7449 - acc: 0.6491 - val_loss: 0.9592 - val_acc: 0.8551
# Epoch 2/25
# 550/550 [==============================] - 33s 59ms/step - loss: 1.4292 - acc: 0.8400 - val_loss: 0.9060 - val_acc: 0.9058
# Epoch 3/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.9492 - acc: 0.8873 - val_loss: 0.3955 - val_acc: 0.8841
# Epoch 4/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.2333 - acc: 0.9182 - val_loss: 0.2427 - val_acc: 0.9058
# Epoch 5/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.1483 - acc: 0.9436 - val_loss: 0.8752 - val_acc: 0.8188
# Epoch 6/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0979 - acc: 0.9673 - val_loss: 0.4569 - val_acc: 0.8986
# Epoch 7/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.0564 - acc: 0.9836 - val_loss: 0.4036 - val_acc: 0.8986
# Epoch 8/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0398 - acc: 0.9855 - val_loss: 0.3881 - val_acc: 0.9058
# Epoch 9/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0951 - acc: 0.9745 - val_loss: 0.3681 - val_acc: 0.9130
# Epoch 10/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0165 - acc: 0.9945 - val_loss: 0.4577 - val_acc: 0.8986
# Epoch 11/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0274 - acc: 0.9945 - val_loss: 0.4082 - val_acc: 0.9130
# Epoch 12/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0233 - acc: 0.9945 - val_loss: 0.4814 - val_acc: 0.8986
# Epoch 13/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0205 - acc: 0.9945 - val_loss: 0.4267 - val_acc: 0.9275
# Epoch 14/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0366 - acc: 0.9927 - val_loss: 0.4360 - val_acc: 0.9058
# Epoch 15/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0285 - acc: 0.9909 - val_loss: 0.5873 - val_acc: 0.8986
# Epoch 16/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0114 - acc: 0.9964 - val_loss: 0.5845 - val_acc: 0.9058
# Epoch 17/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0233 - acc: 0.9964 - val_loss: 0.5585 - val_acc: 0.9058
# Epoch 18/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0304 - acc: 0.9945 - val_loss: 0.4460 - val_acc: 0.9275
# Epoch 19/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0185 - acc: 0.9964 - val_loss: 0.6628 - val_acc: 0.8913
# Epoch 20/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0212 - acc: 0.9964 - val_loss: 0.5379 - val_acc: 0.9058
# Epoch 21/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0189 - acc: 0.9964 - val_loss: 0.5762 - val_acc: 0.9058
# Epoch 22/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0178 - acc: 0.9909 - val_loss: 0.6019 - val_acc: 0.8986
# Epoch 23/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0179 - acc: 0.9964 - val_loss: 0.5906 - val_acc: 0.9058
# Epoch 24/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0185 - acc: 0.9927 - val_loss: 0.5703 - val_acc: 0.9203
# Epoch 25/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0214 - acc: 0.9927 - val_loss: 0.5934 - val_acc: 0.9058
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# Freeze the last 6 layers
print("Freeze the last 6 layers")
for layer in vgg_conv.layers[:-6]:
    layer.trainable = False

# Create the model
model = models.Sequential()

# Add the vgg convolutional base model
model.add(vgg_conv)

# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])
# Train the model

history=model.fit(XTrain, yTrain, epochs=25, batch_size=25,validation_data=valid_data)

print(history.history.keys())
# Save the model
fileName="freeze_last6.h5"
model.save(fileName)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Freeze the last 6 layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 9, 18, 512)        14714688
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              84935680
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 99,653,443
# Trainable params: 87,298,563
# Non-trainable params: 12,354,880
# _________________________________________________________________
# Train on 550 samples, validate on 138 samples
# Epoch 1/25
# 550/550 [==============================] - 36s 66ms/step - loss: 0.5661 - acc: 0.7818 - val_loss: 0.3328 - val_acc: 0.8406
# Epoch 2/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.1233 - acc: 0.9600 - val_loss: 0.2669 - val_acc: 0.9130
# Epoch 3/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.0265 - acc: 0.9909 - val_loss: 0.3141 - val_acc: 0.9130
# Epoch 4/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0363 - acc: 0.9873 - val_loss: 0.5206 - val_acc: 0.9130
# Epoch 5/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0168 - acc: 0.9964 - val_loss: 0.3993 - val_acc: 0.9058
# Epoch 6/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0230 - acc: 0.9964 - val_loss: 0.5253 - val_acc: 0.8986
# Epoch 7/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0161 - acc: 0.9964 - val_loss: 0.4362 - val_acc: 0.9058
# Epoch 8/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.0168 - acc: 0.9927 - val_loss: 1.8662 - val_acc: 0.7826
# Epoch 9/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.0317 - acc: 0.9909 - val_loss: 0.5356 - val_acc: 0.8986
# Epoch 10/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0096 - acc: 0.9927 - val_loss: 0.5851 - val_acc: 0.9058
# Epoch 11/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0163 - acc: 0.9964 - val_loss: 0.4456 - val_acc: 0.9203
# Epoch 12/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0156 - acc: 0.9945 - val_loss: 0.5015 - val_acc: 0.9130
# Epoch 13/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0124 - acc: 0.9927 - val_loss: 0.6059 - val_acc: 0.9058
# Epoch 14/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0224 - acc: 0.9964 - val_loss: 0.6795 - val_acc: 0.9058
# Epoch 15/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0124 - acc: 0.9927 - val_loss: 0.6602 - val_acc: 0.9203
# Epoch 16/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0124 - acc: 0.9964 - val_loss: 0.7405 - val_acc: 0.8913
# Epoch 17/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0206 - acc: 0.9927 - val_loss: 0.6397 - val_acc: 0.9058
# Epoch 18/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0164 - acc: 0.9945 - val_loss: 0.6662 - val_acc: 0.9203
# Epoch 19/25
# 550/550 [==============================] - 33s 59ms/step - loss: 0.0100 - acc: 0.9945 - val_loss: 0.6933 - val_acc: 0.9058
# Epoch 20/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0119 - acc: 0.9945 - val_loss: 0.7540 - val_acc: 0.9130
# Epoch 21/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0150 - acc: 0.9964 - val_loss: 0.6071 - val_acc: 0.9275
# Epoch 22/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0114 - acc: 0.9945 - val_loss: 0.6821 - val_acc: 0.9058
# Epoch 23/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0155 - acc: 0.9945 - val_loss: 0.6581 - val_acc: 0.9275
# Epoch 24/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0149 - acc: 0.9945 - val_loss: 0.6752 - val_acc: 0.9203
# Epoch 25/25
# 550/550 [==============================] - 33s 60ms/step - loss: 0.0113 - acc: 0.9945 - val_loss: 0.7465 - val_acc: 0.9058
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# Freeze the last 3 layers
print("Freeze the last 3 layers")
for layer in vgg_conv.layers[:-3]:
    layer.trainable = False

# Create the model
model = models.Sequential()

# Add the vgg convolutional base model
model.add(vgg_conv)

# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])
# Train the model

history=model.fit(XTrain, yTrain, epochs=25, batch_size=25,validation_data=valid_data)

print(history.history.keys())
# Save the model
fileName="freeze_last3.h5"
model.save(fileName)

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Freeze the last 3 layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 9, 18, 512)        14714688
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              84935680
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 99,653,443
# Trainable params: 87,298,563
# Non-trainable params: 12,354,880
# _________________________________________________________________
# Train on 550 samples, validate on 138 samples
# Epoch 1/25
# 550/550 [==============================] - 38s 70ms/step - loss: 0.3690 - acc: 0.8618 - val_loss: 0.2296 - val_acc: 0.9058
# Epoch 2/25
# 275/550 [==============>...............] - ETA: 14s - loss: 0.0446 - acc: 0.9964
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6fd67b2af669> in <module>()
#      25 # Train the model
#      26
# ---> 27 history=model.fit(XTrain, yTrain, epochs=25, batch_size=25,validation_data=valid_data)
#      28
#      29 print(history.history.keys())
#
# ~/var/python/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~/var/python/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/var/python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/var/python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/var/python/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
